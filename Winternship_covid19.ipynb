# %%
import pandas as pd

# %%
d = pd.read_csv('https://raw.githubusercontent.com/WidhyaOrg/datasets/master/covid19.csv')

# %%
d.head(10)
# Out:
#    Sno      Date State/UnionTerritory  ...  ConfirmedForeignNational  Cured  Deaths
# 0    1  30/01/20               Kerala  ...                         0      0       0
# 1    2  31/01/20               Kerala  ...                         0      0       0
# 2    3  01/02/20               Kerala  ...                         0      0       0
# 3    4  02/02/20               Kerala  ...                         0      0       0
# 4    5  03/02/20               Kerala  ...                         0      0       0
# 5    6  04/02/20               Kerala  ...                         0      0       0
# 6    7  05/02/20               Kerala  ...                         0      0       0
# 7    8  06/02/20               Kerala  ...                         0      0       0
# 8    9  07/02/20               Kerala  ...                         0      0       0
# 9   10  08/02/20               Kerala  ...                         0      0       0
#
# [10 rows x 7 columns]

# %%
d = d.drop(['Sno'], axis=1)

# %%
d1 = d.groupby(d['Date'],sort=False).sum()

# %%
d1
# Out:
#           ConfirmedIndianNational  ConfirmedForeignNational  Cured  Deaths
# Date
# 30/01/20                        1                         0      0       0
# 31/01/20                        1                         0      0       0
# 01/02/20                        2                         0      0       0
# 02/02/20                        3                         0      0       0
# 03/02/20                        3                         0      0       0
# 04/02/20                        3                         0      0       0
# 05/02/20                        3                         0      0       0
# 06/02/20                        3                         0      0       0
# 07/02/20                        3                         0      0       0
# 08/02/20                        3                         0      0       0
# 09/02/20                        3                         0      0       0
# ...

# %%
d1.loc[:,'total_count'] = d1.sum(axis=1)

# %%
d1.tail(20)
# Out:
#           ConfirmedIndianNational  ...  total_count
# Date                               ...
# 02/03/20                        5  ...            5
# 03/03/20                        5  ...            9
# 04/03/20                       12  ...           31
# 05/03/20                       14  ...           33
# 06/03/20                       15  ...           34
# 07/03/20                       18  ...           37
# 08/03/20                       23  ...           42
# 09/03/20                       30  ...           49
# 10/03/20                       42  ...           61
# 11/03/20                       44  ...           63
# 12/03/20                       57  ...           77
# 13/03/20                       64  ...           85
# 14/03/20                       67  ...           96
# 15/03/20                       93  ...          125
# 16/03/20                       97  ...          129
# 17/03/20                      113  ...          154
# ...

# %%
d2 = d1.reset_index()

# %%
d2
# Out:
#         Date  ConfirmedIndianNational  ...  Deaths  total_count
# 0   30/01/20                        1  ...       0            1
# 1   31/01/20                        1  ...       0            1
# 2   01/02/20                        2  ...       0            2
# 3   02/02/20                        3  ...       0            3
# 4   03/02/20                        3  ...       0            3
# 5   04/02/20                        3  ...       0            3
# 6   05/02/20                        3  ...       0            3
# 7   06/02/20                        3  ...       0            3
# 8   07/02/20                        3  ...       0            3
# 9   08/02/20                        3  ...       0            3
# 10  09/02/20                        3  ...       0            3
# 11  10/02/20                        3  ...       0            3
# 12  11/02/20                        3  ...       0            3
# 13  12/02/20                        3  ...       0            3
# ...

# %%
x = d2.Date

# %%
y= d2.total_count

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)
plt.show()

# %%
new = d2.iloc[34:,]

# %%
new
# Out:
#         Date  ConfirmedIndianNational  ...  Deaths  total_count
# 34  04/03/20                       12  ...       0           31
# 35  05/03/20                       14  ...       0           33
# 36  06/03/20                       15  ...       0           34
# 37  07/03/20                       18  ...       0           37
# 38  08/03/20                       23  ...       0           42
# 39  09/03/20                       30  ...       0           49
# 40  10/03/20                       42  ...       0           61
# 41  11/03/20                       44  ...       0           63
# 42  12/03/20                       57  ...       0           77
# 43  13/03/20                       64  ...       1           85
# 44  14/03/20                       67  ...       2           96
# 45  15/03/20                       93  ...       2          125
# 46  16/03/20                       97  ...       2          129
# 47  17/03/20                      113  ...       3          154
# ...

# %% [markdown]
# P_t = P_o * (e^(r*t))

# %%
a = d2['total_count'].pct_change(fill_method ='ffill')

# %%
r = a.mean(axis = 0)

# %%
P_o = 31
t = 26

# %%
P_t= P_o*(pow(2.718281828459045,t*r))

# %%
P_t
# Out:
# 1766.1238891651092
